# %%
from PIL import Image
import numpy as np
import os


train = os.listdir("./train/audio_small/1000_dog/spectrograms/")
im = Image.open

im("./train/audio_small/1000_dog/spectrograms/00b01445_nohash_0.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=512x256 at 0x7F47370A7E48>

# %%
im("./small_test/spectrograms/clip_000044442.png").size
# Out:
# (512, 256)

# %%
#im('/train/0951c3054.jpg').resize((200, 200))

# Taking a shrinked version of the image to avoid unnecessary computation
#img = im('/train/0951c3054.jpg').resize((200, 200))
img = im("./small_test/spectrograms/clip_000044442.png")

rgb_pixels = np.array(img)
rgb_pixels.shape
# Out:
# (256, 512)

# %%
rgb_pixels.shape
# Out:
# (256, 512)

# %%
# Red saturation of the top-left most 2x2 square pixels
rgb_pixels[0:2, 0:2, 0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-13133661726d> in <module>()
#       1 # Red saturation of the top-left most 2x2 square pixels
# ----> 2 rgb_pixels[0:2, 0:2, 0]
#
# IndexError: too many indices for array

# %%
import matplotlib.pyplot as plt
plt.imshow(rgb_pixels);

# %%
# Note that imshow can plot a 1-channel image on monochrome
plt.imshow(rgb_pixels[:, :, 1], cmap='Greys');
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-611502b8beb5> in <module>()
#       1 # Note that imshow can plot a 1-channel image on monochrome
# ----> 2 plt.imshow(rgb_pixels[:, :, 1], cmap='Greys');
#
# IndexError: too many indices for array

# %%
plt.imshow(rgb_pixels)
plt.title("Full image"); # We can add a title with plt.title()
plt.show()

plt.imshow(rgb_pixels[0:200,0:100]) # And with can crop the image using standard python slicing
plt.title("Left half");
plt.show()

plt.imshow(rgb_pixels[0:200,100:200])
plt.title("Right half");
plt.show()

# %%
# these two variables are "the parameters" of this cell
w = 10
h = 10

train = os.listdir("./train/audio_small/other/spectrograms/")
# this function uses the open, resize and array functions we have seen before
load_img = lambda filename: np.array(im(f"./train/audio_small/other/spectrograms/{filename}"))

_, axes_list = plt.subplots(h, w, figsize=(2*w, 2*h)) # define a grid of (w, h)

for axes in axes_list:
    for ax in axes:
        ax.axis('off')
        img = np.random.choice(train) # take a random train filename (like 000c34352.jpg)
        ax.imshow(load_img(img)) # load and show
        ax.set_title(img)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-afbdf33aed57> in <module>()
# ----> 1 im.shape
#
# AttributeError: 'function' object has no attribute 'shape'
